# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

Product_name = []
Prices = []
Description = []
Reviews = []

for i in range(2, 8):
    url = "https://www.flipkart.com/search?q=phones+under+50k&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_16_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_16_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=phones+under+50k%7CMobiles&requestId=ff49bde7-71a3-487c-9053-99a7a138b511&as-searchtext=phones+under+50k&page=" + str(i)
        
    r = requests.get(url)
    # print(r)
    soup = BeautifulSoup(r.text, "html.parser")
    box = soup.find("div", class_="_1YokD2 _3Mn1Gg")

    # print(soup)

    name = box.find_all("div", class_="_4rR01T")

    for i in name:
        name = i.text
        Product_name.append(name)

    # print(Product_name)

    prices = box.find_all("div", class_="_30jeq3 _1_WHN1")

    for i in prices:
        name = i.text
        Prices.append(name)

    # print(Prices)

    desc = box.find_all("ul", class_="_1xgFaf")

    for i in desc:
        name = i.text
        Description.append(name)

    # print(Description)

    rev = box.find_all("div", class_="_3LWZlK")

    for i in rev:
        name = i.text
        Reviews.append(name)

# print(len(Reviews))

dic = {
    "Name": Product_name,
    "Prices": Prices,
    "Descriptions": Description,
    "Reviews": Reviews
}

final_data = pd.DataFrame.from_dict(dic, orient="index")
final_data = final_data.transpose()

#print(final_data)

final_data.to_csv("Flipkart1.csv",index=False)
